# %%
# !pip install earthengine-api
import ee
# !pip install geemap
import geemap
# Out:
# Requirement already satisfied: earthengine-api in c:\users\asus\anaconda3\envs\gee\lib\site-packages (0.1.270)
# Requirement already satisfied: future in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (0.18.2)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (1.12.8)
# Requirement already satisfied: google-cloud-storage in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (1.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (0.19.1)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (1.31.0)
# Requirement already satisfied: httplib2shim in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (0.0.3)
# Requirement already satisfied: six in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api) (1.16.0)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api) (1.30.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api) (3.0.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (20.9)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (52.0.0.post20210125)
# Requirement already satisfied: pytz in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2021.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2.25.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (3.17.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.2.8)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2.10)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-cloud-storage->earthengine-api) (1.7.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.2.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-cloud-storage->earthengine-api) (1.3.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage->earthengine-api) (1.1.2)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage->earthengine-api) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage->earthengine-api) (2.20)
# Requirement already satisfied: geemap in c:\users\asus\anaconda3\envs\gee\lib\site-packages (0.8.16)
# Requirement already satisfied: ipyfilechooser in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.4.3)
# Requirement already satisfied: folium>=0.11.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.12.1)
# Requirement already satisfied: bqplot in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.12.29)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (1.2.4)
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (3.4.2)
# Requirement already satisfied: googledrivedownloader in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.4)
# Requirement already satisfied: earthengine-api>=0.1.230 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.1.270)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (2.1.3)
# Requirement already satisfied: pycrs in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (1.0.2)
# Requirement already satisfied: ipyleaflet<=0.13.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.13.3)
# Requirement already satisfied: ipytree in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.2.1)
# Requirement already satisfied: mss in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (6.1.0)
# Requirement already satisfied: voila in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.2.10)
# Requirement already satisfied: whiteboxgui in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.3.0)
# Requirement already satisfied: ipyevents in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.8.2)
# Requirement already satisfied: pillow in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (8.2.0)
# Requirement already satisfied: python-box in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (5.3.0)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (1.20.2)
# Requirement already satisfied: geocoder in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: click in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (7.1.2)
# Requirement already satisfied: geeadd>=0.5.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.5.5)
# Requirement already satisfied: ffmpeg-python in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.2.0)
# Requirement already satisfied: ipynb-py-convert in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.4.6)
# Requirement already satisfied: colour in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.1.0)
# Requirement already satisfied: google-cloud-storage in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.38.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.19.1)
# Requirement already satisfied: future in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.18.2)
# Requirement already satisfied: httplib2shim in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.0.3)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.12.8)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.31.0)
# Requirement already satisfied: six in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.16.0)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from folium>=0.11.0->geemap) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from folium>=0.11.0->geemap) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from folium>=0.11.0->geemap) (3.0.1)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geeadd>=0.5.1->geemap) (4.9.3)
# Requirement already satisfied: logzero>=1.5.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.2.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.30.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.53.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=14.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (20.9)
# Requirement already satisfied: pytz in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (2021.1)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.2.2)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=0.1.230->geemap) (2.4.7)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipyleaflet<=0.13.3->geemap) (7.6.3)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipyleaflet<=0.13.3->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.5.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (7.24.1)
# Requirement already satisfied: jupyter-client in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.1)
# Requirement already satisfied: backcall in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.0.18)
# Requirement already satisfied: pygments in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (2.9.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.7.5)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.4.4)
# Requirement already satisfied: decorator in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (4.7.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.17.3)
# Requirement already satisfied: wcwidth in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests->folium>=0.11.0->geemap) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests->folium>=0.11.0->geemap) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests->folium>=0.11.0->geemap) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.4.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.9.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (22.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (300)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (2.20)
# Requirement already satisfied: ratelim in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.2.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.3.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.1.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: defusedxml in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.4.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.3)
# Requirement already satisfied: testpath in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.0)
# Requirement already satisfied: bleach in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.1)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from voila->geemap) (1.8.0)
# Requirement already satisfied: websocket-client in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (1.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (3.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila->geemap) (1.2.0)
# Requirement already satisfied: whitebox in c:\users\asus\anaconda3\envs\gee\lib\site-packages (from whiteboxgui->geemap) (1.5.1)

# %%
Map = geemap.Map(center=(0.036, 102.0157), zoom=13)
Map
# Out:
# Map(center=[0.036, 102.0157], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton…

# %%
#Definisikan Daerah Penelitian
geometry2 = ee.Geometry.Polygon(
        [[[101.93336117527792, 0.06990952997337596],
          [101.93336117527792, -0.06707621616689373],
          [102.0696603085787, -0.06707621616689373],
          [102.0696603085787, 0.06990952997337596]]])
sctrA = ee.FeatureCollection("users/rifkynauvalhsp/healthmonitoring/SectorA")
def maskS2clouds(img):
  cloudBitMask = 1 << 10;
  cirrusBitMask = 1 << 11;
  # Get the pixel QA band.
  qa = img.select('QA60')
  # Both flags should be set to zero, indicating clear conditions.
  mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0))
  return img.updateMask(mask).divide(10000)

def addindices(image): 
  ndvi = image.normalizedDifference(['B8', 'B4']).rename(['ndvi']);
  gndvi = image.normalizedDifference(['B2', 'B4']).rename(['gndvi']);
  ndmi = image.normalizedDifference(['B8', 'B11']).rename(['ndmi']);
  savi = image.expression('(NIR-RED)/(NIR+RED+0.5)*(1.5)',{
  'NIR' : image.select('B8'),
  'RED':image.select('B4')
}).rename('savi')
  evi = image.expression('2.5*((NIR-RED)/(NIR+(RED*2.4)+1))',{
  'NIR' : image.select('B8'),
  'RED':image.select('B4')
}).rename('evi')
  
  return image.addBands(ndvi).addBands(gndvi).addBands(ndmi).addBands(savi).addBands(evi)
dataset = ee.ImageCollection('COPERNICUS/S2_SR').select(['QA60','B2','B3','B4','B8','B11']).filterBounds(sctrA).filterDate('2020-01-01', '2020-12-30').filterMetadata('CLOUDY_PIXEL_PERCENTAGE', 'less_than', 3).map(maskS2clouds).map(addindices);
image = dataset.mean()
Map.addLayer(image, {'bands': ['B4', 'B3', 'B2'], 'max': 0.3}, "image")

# %%
mean = ee.Number(image.select('ndvi').reduceRegion(**{'geometry': geometry2,
'reducer': ee.Reducer.mean(),'scale': 30,
'maxPixels': 1e9
}).values().get(0))

standev = ee.Number(image.select('ndvi').reduceRegion(**{'geometry': geometry2,
'reducer': ee.Reducer.stdDev(),'scale': 30,
'maxPixels': 1e9
}).values().get(0))

zscore = image.expression('((ndvi-mean)/standev)',{
  'ndvi' : image.select('ndvi'),
  'mean':mean,
  'standev':standev,
}).rename('Zscore')
    
image = image.addBands(zscore)

# %%
# Load watersheds from a Fusion Table.
sctrA = ee.FeatureCollection("users/rifkynauvalhsp/healthmonitoring/SectorA")
sctrB = ee.FeatureCollection("users/rifkynauvalhsp/healthmonitoring/SectorB")
sctrC = ee.FeatureCollection("users/rifkynauvalhsp/healthmonitoring/SectorC")
sctrD = ee.FeatureCollection("users/rifkynauvalhsp/healthmonitoring/SectorD")
# Add the mean of each image as new properties of each feature.


# This function computes the feature's geometry area and adds it as a property.
def addAreaA(feature):
  
  result = image.reduceRegion(**{
    'reducer':ee.Reducer.mean(),
  'geometry': feature.geometry(),
  'scale': 30,
  'crs': 'EPSG:5070',
  'bestEffort': True,
  'maxPixels': 1e12,
 
  })
 
  feature = feature.set({'Estate': 'A'})
  feature = feature.set({'RED': result.get('B4')})
  feature = feature.set({'GREEN': result.get('B3')})
  feature = feature.set({'BLUE': result.get('B2')})
  feature = feature.set({'NIR': result.get('B8')}) 
  feature = feature.set({'NDVI': result.get('ndvi')})
  feature = feature.set({'GNDVI': result.get('gndvi')})
  feature = feature.set({'NDMI': result.get('ndmi')})
  feature = feature.set({'SAVI': result.get('savi')})
  feature = feature.set({'EVI': result.get('evi')})
  feature = feature.set({'Zscore': result.get('Zscore')})
  #feature = feature.set({'Significance':  ee.Algorithms.If(ee.Number.parse((result.get('Zscore').values()) > ee.Number.parse(-1.96), "Significance","Not Significance"))});
  return feature
# This function computes the feature's geometry area and adds it as a property.
def csvInfoA1(feature):
  feature = feature.set({'class': 'Healthy'})
  return feature

def csvInfoA2(feature):
  feature = feature.set({'class': 'Unhealthy'})
  return feature

# Map the area getting function over the FeatureCollection.
areaAddedA = sctrA.map(addAreaA)



# Print the first feature from the collection with the added property.
#print('First feature: \n')
#pprint(areaAdded.limit(50).getInfo())
HealthyA = areaAddedA.filter(ee.Filter.gt('NDVI', 0.7))
UnhealthyA = areaAddedA.filter(ee.Filter.lt('NDVI', 0.7))
HealthyA1 = HealthyA.map(csvInfoA1)
UnhealthyA1 = UnhealthyA.map(csvInfoA2)
#numHealthyA = HealthyA.size().getInfo()
#numUnhealthyA = UnhealthyA.size().getInfo()
#conditionalA =  ee.Algorithms.If(numHealthyA > numUnhealthyA, 'green',  'red' )
#colorsA = conditionalA.getInfo()
Map.addLayer(HealthyA, {'color': 'green'}, 'Healthy A');
Map.addLayer(UnhealthyA, {'color': 'red'}, 'Unhealthy A');
#Map.addLayer(sctrA,{'color': colorsA}, 'Estate A')

# %%
# This function computes the feature's geometry area and adds it as a property.
def addAreaB(feature):
  
  result = image.reduceRegion(**{
    'reducer':ee.Reducer.mean(),
  'geometry': feature.geometry(),
  'scale': 30,
  'crs': 'EPSG:5070',
  'bestEffort': True,
  'maxPixels': 1e12,
 
  })
 
  feature = feature.set({'Estate': 'B'})
  feature = feature.set({'RED': result.get('B4')})
  feature = feature.set({'GREEN': result.get('B3')})
  feature = feature.set({'BLUE': result.get('B2')})
  feature = feature.set({'NIR': result.get('B8')}) 
  feature = feature.set({'NDVI': result.get('ndvi')})
  feature = feature.set({'GNDVI': result.get('gndvi')})
  feature = feature.set({'NDMI': result.get('ndmi')})
  feature = feature.set({'SAVI': result.get('savi')})
  feature = feature.set({'EVI': result.get('evi')})
  feature = feature.set({'Zscore': result.get('Zscore')})
  return feature

areaAddedB = sctrB.map(addAreaB)

HealthyB = areaAddedB.filter(ee.Filter.gt('NDVI', 0.7))
UnhealthyB = areaAddedB.filter(ee.Filter.lt('NDVI', 0.7))
HealthyB1 = HealthyB.map(csvInfoA1)
UnhealthyB1 = UnhealthyB.map(csvInfoA2)
#numHealthyB = HealthyB.size().getInfo()
#numUnhealthyB = UnhealthyB.size().getInfo()
#conditionalB =  ee.Algorithms.If(numHealthyB > numUnhealthyB, 'green',  'red' )
#colorsB = conditionalB.getInfo()
Map.addLayer(HealthyB, {'color': 'green'}, 'Healthy B');
Map.addLayer(UnhealthyB, {'color': 'red'}, 'Unhealthy B');
#Map.addLayer(sctrB,{'color': colorsA}, 'Estate B')

# %%
# This function computes the feature's geometry area and adds it as a property.
def addAreaC(feature):
  
  result = image.reduceRegion(**{
    'reducer':ee.Reducer.mean(),
  'geometry': feature.geometry(),
  'scale': 30,
  'crs': 'EPSG:5070',
  'bestEffort': True,
  'maxPixels': 1e12,
 
  })
 
  feature = feature.set({'Estate': 'C'})
  feature = feature.set({'RED': result.get('B4')})
  feature = feature.set({'GREEN': result.get('B3')})
  feature = feature.set({'BLUE': result.get('B2')})
  feature = feature.set({'NIR': result.get('B8')}) 
  feature = feature.set({'NDVI': result.get('ndvi')})
  feature = feature.set({'GNDVI': result.get('gndvi')})
  feature = feature.set({'NDMI': result.get('ndmi')})
  feature = feature.set({'SAVI': result.get('savi')})
  feature = feature.set({'EVI': result.get('evi')})
  feature = feature.set({'Zscore': result.get('Zscore')})
  return feature

areaAddedC = sctrC.map(addAreaC)
HealthyC = areaAddedC.filter(ee.Filter.gt('NDVI', 0.7))
UnhealthyC = areaAddedC.filter(ee.Filter.lt('NDVI', 0.7))
HealthyC1 = HealthyC.map(csvInfoA1)
UnhealthyC1 = UnhealthyC.map(csvInfoA2)
#numHealthyC = HealthyC.size().getInfo()
#numUnhealthyC = UnhealthyC.size().getInfo()
#conditionalC =  ee.Algorithms.If(numHealthyC > numUnhealthyC, 'green',  'red' )
#colorsC = conditionalC.getInfo()
Map.addLayer(HealthyC, {'color': 'green'}, 'Healthy C');
Map.addLayer(UnhealthyC, {'color': 'red'}, 'Unhealthy C');
#Map.addLayer(sctrC,{'color': colorsA}, 'Estate C')

# %%
# This function computes the feature's geometry area and adds it as a property.
def addAreaD(feature):
  
  result = image.reduceRegion(**{
    'reducer':ee.Reducer.mean(),
  'geometry': feature.geometry(),
  'scale': 30,
  'crs': 'EPSG:5070',
  'bestEffort': True,
  'maxPixels': 1e12,
 
  })
 
  feature = feature.set({'Estate': 'D'})
  feature = feature.set({'RED': result.get('B4')})
  feature = feature.set({'GREEN': result.get('B3')})
  feature = feature.set({'BLUE': result.get('B2')})
  feature = feature.set({'NIR': result.get('B8')}) 
  feature = feature.set({'NDVI': result.get('ndvi')})
  feature = feature.set({'GNDVI': result.get('gndvi')})
  feature = feature.set({'NDMI': result.get('ndmi')})
  feature = feature.set({'SAVI': result.get('savi')})
  feature = feature.set({'EVI': result.get('evi')})
  feature = feature.set({'Zscore': result.get('Zscore')})
  return feature


areaAddedD = sctrD.map(addAreaD)
HealthyD = areaAddedD.filter(ee.Filter.gt('NDVI', 0.7))
UnhealthyD = areaAddedD.filter(ee.Filter.lt('NDVI', 0.7))
HealthyD1 = HealthyD.map(csvInfoA1)
UnhealthyD1 = UnhealthyD.map(csvInfoA2)
# Check the number of watersheds after filtering for size and location.
#numHealthyD = HealthyD.size().getInfo()
#numUnhealthyD = UnhealthyD.size().getInfo()
#conditionalD =  ee.Algorithms.If(numHealthyD > numUnhealthyD, 'green',  'red' )
#colorsD = conditionalD.getInfo()
Map.addLayer(HealthyD, {'color': 'green'}, 'Healthy D');
Map.addLayer(UnhealthyD, {'color': 'red'}, 'Unhealthy D');
#Map.addLayer(sctrD,{'color': colorsD}, 'Estate D')

# %%
# Check the number of watersheds after filtering for size and location.
numHealthyD = HealthyD.size()
numUnhealthyD = UnhealthyD.size()
conditionalD =  ee.Algorithms.If(numHealthyD > numUnhealthyD, 'green',  'red' )
colorsD = conditionalD.getInfo()
Map.addLayer(sctrD,{'color': colorsD}, 'Estate D'

# %%
kesehatantanaman = HealthyA1.merge(UnhealthyA1).merge(HealthyB1).merge(UnhealthyB1).merge(HealthyC1).merge(UnhealthyC1).merge(HealthyD1).merge(UnhealthyD1)
# Export the FeatureCollection to a KML file.
task = ee.batch.Export.table.toDrive(**{
  'collection': kesehatantanaman,
  'description':'EVI6',
  'fileFormat': 'CSV',
  'selectors' : ['Estate','Compartmen', 'RED','GREEN','BLUE','NIR','NDVI', 'GNDVI', 'EVI','NDMI', 'SAVI', 'GNDVI', 'EVI','class','Zscore','Significance'] 
})
task.start()

# %%
import time 
while task.active():
  print('Polling for task (id: {}).'.format(task.id))
  time.sleep(5)
# Out:
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
# Polling for task (id: OT4SXLIMBZUCGCY5PIBMV5B5).
